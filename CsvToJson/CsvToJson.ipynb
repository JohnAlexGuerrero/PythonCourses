# %%
import pandas as pd

# %%
df = pd.read_csv('./data/discografia.csv')

# %%
res = []
text = {}

for i in range(len(df)):
    text = dict(df.iloc[i])
    res.append(text)

# %%
res
# Out:
# [{'id': 1,
#   'title': '🪐',
#   'artist': 'coldplay',
#   'album': 'Music Of The Spheres',
#   'duration': '53,184',
#   'thumbnail': 'coldplay/music_of_the_spheres.jpeg',
#   'url': 'coldplay/🪐.MP3',
#   'published_date': 2000},
#  {'id': 2,
#   'title': 'Higher Power',
#   'artist': 'coldplay',
#   'album': 'Music Of The Spheres',
#   'duration': '206,681',
#   'thumbnail': 'coldplay/music_of_the_spheres.jpeg',
#   'url': 'coldplay/higher_power.MP3',
#   'published_date': 2000},
#  {'id': 3,
#   'title': 'Humankind',
#   'artist': 'coldplay',
#   'album': 'Music Of The Spheres',
#   'duration': '266,704',
#   'thumbnail': 'coldplay/music_of_the_spheres.jpeg',
#   'url': 'coldplay/humankind.MP3',
#   'published_date': 2000},
#  {'id': 4,
#   'title': '✨',
#   'artist': 'coldplay',
#   'album': 'Music Of The Spheres',
#   'duration': '53,033',
#   'thumbnail': 'coldplay/music_of_the_spheres.jpeg',
#   'url': 'coldplay/✨.MP3',
#   'published_date': 2000},
#  {'id': 5,
# ...
